# %%
## plot within the notebook
# %matplotlib inline
import warnings
import numpy as np
## No annoying warnings
warnings.filterwarnings('ignore')

# %%
import simsurvey.cadence as simul
tr = simul.get_transient_generator([0.01,0.02], ratekind="basiclow", type_="Ia")
# ratekind is the rate of the transient: basiclow = 1e3 
# -> comoving volumetric rate at each redshift in units of yr^-1 Mpc^-3.
# type_ is the type of transient. 
# This will parse the ratekind+type_ do get the good rate function

# %%
tr.show_skycoverage(cscale=tr.mwebmv,cblabel="SFD98 dust map MW E(B-V) extinction")
# Out:
# {'ax': <matplotlib.projections.geo.MollweideAxes at 0x109e27ad0>,
#  'cbar': <matplotlib.colorbar.Colorbar instance at 0x109e103f8>,
#  'figure': <matplotlib.figure.Figure at 0x109df8e10>,
#  'plot': <matplotlib.collections.PathCollection at 0x109ea9d50>}
